# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd

driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()))

driver.get('https://fundamentus.com.br/resultado.php')

local_tabela = '/html/body/div[1]/div[2]/table'
tabela = driver.find_element('xpath', local_tabela)
html_tabela = tabela.get_attribute('outerHTML')
tabela = pd.read_html(str(html_tabela),thousands = '.', decimal = ',')[0]

tabela = tabela.set_index('Papel')

tabela.sort_index

tabela = tabela[['Cotação', 'EV/EBIT', 'ROIC', 'Liq.2meses']]
tabela['ROIC'] = tabela['ROIC'].str.replace("%", "")
tabela['ROIC'] = tabela['ROIC'].str.replace(".", "")
tabela['ROIC'] = tabela['ROIC'].str.replace(",", ".")
tabela['ROIC'] = tabela['ROIC'].astype(float)
tabela = tabela[tabela['Liq.2meses'] > 1000000]
tabela = tabela[tabela['EV/EBIT'] > 0]
tabela = tabela[tabela['ROIC'] > 0]
tabela['ranking_ev_ebit'] = tabela['EV/EBIT'].rank(ascending = True)
tabela['ranking_roic'] = tabela['ROIC'].rank(ascending = False)
tabela['ranking_final'] = tabela['ranking_ev_ebit'] + tabela['ranking_roic']

tabela = tabela.sort_values('ranking_final')

# %%
tabela.head(30)
# Out:
#         Cotação  EV/EBIT   ROIC    Liq.2meses  ranking_ev_ebit  ranking_roic  \
# Papel
# PSSA3     25.61     0.21  60.76  3.291960e+07              1.0           1.0
# PETR4     35.12     2.59  28.95  1.763320e+09              4.0           9.5
# PETR3     38.28     2.74  28.95  4.676050e+08              5.0           9.5
# UNIP6     71.96     4.53  38.68  1.573220e+07             12.5           2.0
# WIZC3      5.07     1.90  24.18  3.999120e+06              3.0          16.0
# FESA4     47.10     4.53  25.57  8.457770e+06             12.5          14.0
# PLPL3      9.06     5.10  30.59  1.300870e+07             23.0           7.0
# VLID3     16.19     4.02  20.64  5.911810e+06              8.0          23.0
# GOAU4     10.51     1.34  19.35  7.601590e+07              2.0          31.0
# KEPL3      9.95     5.50  33.03  1.308400e+07             29.0           5.0
# GGBR3     20.25     3.42  19.39  1.093330e+06              6.0          29.5
# GGBR4     22.18     3.70  19.39  2.047420e+08              7.0          29.5
# TASA4     14.85     5.04  24.33  6.472080e+06             22.0          15.0
# LEVE3     36.43     5.79  36.32  2.616010e+07             37.5           4.0
# VALE3     70.32     4.62  20.11  1.626320e+09             17.0          25.0
# LREN3     12.27     4.08  17.55  2.973940e+08              9.0          36.0
# PRNR3     10.45     4.91  20.01  2.584140e+06             21.0          26.0
# AURA33    32.04     5.15  19.72  1.447450e+06             24.0          27.0
# CMIN3      5.33     6.02  28.49  4.292170e+07             40.0          11.0
# CMIG4     12.24     4.44  16.35  1.063870e+08             10.0          43.5
# RECV3     21.11     5.52  19.43  6.528760e+07             30.0          28.0
# BEEF3      7.60     5.69  20.21  7.697770e+07             35.0          24.0
# SAPR3      4.39     4.50  15.20  1.224190e+06             11.0          51.0
# RAPT4     11.07     4.63  15.57  1.904940e+07             18.0          47.0
# SAPR4      4.50     4.56  15.20  8.551400e+06             14.5          51.0
# SAPR11    22.43     4.56  15.20  2.999260e+07             14.5          51.0
# CSUD3     16.54     6.48  21.84  1.036300e+06             47.0          19.0
# CURY3     15.00     7.27  29.54  2.830570e+07             62.0           8.0
# TGMA3     24.60     7.10  25.60  4.126440e+06             57.0          13.0
# CPFE3     33.95     5.53  16.48  5.793320e+07             31.0          41.0
#
#         ranking_final
# Papel
# PSSA3             2.0
# PETR4            13.5
# PETR3            14.5
# UNIP6            14.5
# WIZC3            19.0
# FESA4            26.5
# PLPL3            30.0
# VLID3            31.0
# GOAU4            33.0
# KEPL3            34.0
# GGBR3            35.5
# GGBR4            36.5
# TASA4            37.0
# LEVE3            41.5
# VALE3            42.0
# LREN3            45.0
# PRNR3            47.0
# AURA33           51.0
# CMIN3            51.0
# CMIG4            53.5
# RECV3            58.0
# BEEF3            59.0
# SAPR3            62.0
# RAPT4            65.0
# SAPR4            65.5
# SAPR11           65.5
# CSUD3            66.0
# CURY3            70.0
# TGMA3            70.0
# CPFE3            72.0
