# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from io import StringIO

chrome_options = Options()
chrome_options.add_argument('--headless')
driver = webdriver.Chrome(service = Service(ChromeDriverManager().install()), options=chrome_options)

driver.get('https://fundamentus.com.br/resultado.php')

local_tabela = '/html/body/div[1]/div[2]/table'
tabela = driver.find_element('xpath', local_tabela)
html_tabela = tabela.get_attribute('outerHTML')
tabela = pd.read_html(StringIO(str(html_tabela)),thousands = '.', decimal = ',')[0]

tabela = tabela.set_index('Papel')

tabela.sort_index

tabela = tabela[['Cotação', 'EV/EBIT', 'ROIC', 'Liq.2meses']]
tabela['ROIC'] = tabela['ROIC'].str.replace("%", "")
tabela['ROIC'] = tabela['ROIC'].str.replace(".", "")
tabela['ROIC'] = tabela['ROIC'].str.replace(",", ".")
tabela['ROIC'] = tabela['ROIC'].astype(float)
tabela = tabela[tabela['Liq.2meses'] > 1000000]
tabela = tabela[tabela['EV/EBIT'] > 0]
tabela = tabela[tabela['ROIC'] > 0]
tabela['ranking_ev_ebit'] = tabela['EV/EBIT'].rank(ascending = True)
tabela['ranking_roic'] = tabela['ROIC'].rank(ascending = False)
tabela['ranking_final'] = tabela['ranking_ev_ebit'] + tabela['ranking_roic']
tabela = tabela.sort_values('ranking_final')
tabela.head(30)
# Out:
#         Cotação  EV/EBIT   ROIC    Liq.2meses  ranking_ev_ebit  ranking_roic  \
# Papel
# PSSA3     31.00     0.30  83.01  5.036030e+07              1.0           1.0
# CMIN3      5.08     3.84  37.86  4.780040e+07             10.0           4.0
# WIZC3      7.05     2.20  25.65  3.078100e+06              3.0          13.0
# PLPL3     13.88     4.78  42.81  9.361470e+06             17.0           2.0
# PETR4     39.30     3.13  24.87  1.904310e+09              5.0          14.5
# PETR3     40.63     3.20  24.87  5.973360e+08              6.0          14.5
# VLID3     17.90     3.75  23.84  7.611920e+06              8.0          16.0
# VALE3     61.86     3.87  20.67  1.660540e+09             11.0          22.0
# GOLL4      1.49     4.33  17.35  2.235090e+07             12.0          32.0
# LEVE3     35.23     6.55  38.76  1.781840e+07             42.0           3.0
# LREN3     16.69     5.25  18.19  2.177650e+08             24.0          26.0
# UNIP6     64.31     6.45  25.97  1.284320e+07             40.0          11.0
# KEPL3     10.49     6.56  26.46  1.160340e+07             43.0          10.0
# SAPR3      4.89     4.38  15.82  1.279730e+06             13.0          41.5
# CIEL3      5.40     6.15  19.34  1.061700e+08             32.0          23.0
# SAPR11    25.30     4.47  15.82  2.060380e+07             14.0          41.5
# SAPR4      5.11     4.50  15.82  9.676810e+06             15.0          41.5
# GOAU4     10.75     1.80  14.30  7.082960e+07              2.0          56.0
# CPFE3     35.29     5.51  16.99  7.707640e+07             26.0          34.0
# QUAL3      1.56     3.83  14.53  1.356020e+07              9.0          53.0
# RAPT4     13.29     4.99  15.68  1.928780e+07             19.0          44.0
# ASAI3     14.18     6.31  17.88  1.400240e+08             36.0          29.0
# PRIO3     49.80     7.28  28.21  4.218330e+08             57.0           9.0
# CMIG4     13.11     4.85  15.10  1.479820e+08             18.0          48.5
# GGBR3     20.41     4.54  14.34  1.050400e+06             16.0          54.5
# BEEF3      6.50     6.32  16.65  6.670500e+07             37.0          35.0
# CSUD3     19.25     7.04  22.64  1.253460e+06             51.0          21.0
# CMIG3     15.16     5.45  15.10  5.796740e+06             25.0          48.5
# GGBR4     22.87     5.01  14.34  2.317340e+08             20.0          54.5
# AURA33    40.65     6.61  17.58  2.579160e+06             44.0          31.0
#
#         ranking_final
# Papel
# PSSA3             2.0
# CMIN3            14.0
# WIZC3            16.0
# PLPL3            19.0
# PETR4            19.5
# PETR3            20.5
# VLID3            24.0
# VALE3            33.0
# GOLL4            44.0
# LEVE3            45.0
# LREN3            50.0
# UNIP6            51.0
# KEPL3            53.0
# SAPR3            54.5
# CIEL3            55.0
# SAPR11           55.5
# SAPR4            56.5
# GOAU4            58.0
# CPFE3            60.0
# QUAL3            62.0
# RAPT4            63.0
# ASAI3            65.0
# PRIO3            66.0
# CMIG4            66.5
# GGBR3            70.5
# BEEF3            72.0
# CSUD3            72.0
# CMIG3            73.5
# GGBR4            74.5
# AURA33           75.0
